# %% [markdown]
# # Time Series Analysis - Probabilistic Forecasting
#
# This notebook demonstrates the capabilities of the Time Series Analysis project, focusing on probabilistic forecasting with multiple models.
#
# ## Overview
# - Generate synthetic time series data
# - Train multiple forecasting models (Prophet, ARIMA, LSTM)
# - Perform probabilistic forecasting with confidence intervals
# - Detect anomalies in the data
# - Visualize results and compare model performance
